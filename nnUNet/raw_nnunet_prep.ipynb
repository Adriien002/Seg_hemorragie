# %% [markdown]
# # Prepare dataset for nnunet training with z-norm

# %%
import os
import numpy as np
import nibabel as nib

def rename_images(input_folder, output_folder):
    """Copy images to new folder with _0000 suffix added"""
    
    print("STEP 1: COPYING AND RENAMING IMAGES")
    print("=" * 40)
    print(f"Input folder: {input_folder}")
    print(f"Output folder: {output_folder}")
    
    if not os.path.exists(input_folder):
        print(f" Error: Input folder does not exist: {input_folder}")
        return False
    
    # Create output folder
    os.makedirs(output_folder, exist_ok=True)
    
    copied_count = 0
    total_files = 0
    
    for filename in os.listdir(input_folder):
        if filename.endswith(".nii.gz"):
            total_files += 1
            
            input_path = os.path.join(input_folder, filename)
            
            # Add _0000 if not present
            if "_0000" not in filename:
                new_filename = filename.replace(".nii.gz", "_0000.nii.gz")
            else:
                new_filename = filename
            
            output_path = os.path.join(output_folder, new_filename)
            
            try:
                # Load and save to copy the file
                nii_image = nib.load(input_path)
                nib.save(nii_image, output_path)
                
                if "_0000" not in filename:
                    print(f" Copied & renamed: {filename} ➜ {new_filename}")
                else:
                    print(f" Copied: {filename}")
                copied_count += 1
                
            except Exception as e:
                print(f"Error copying {filename}: {str(e)}")
    
    print(f"\nCopying Summary:")
    print(f"   Total .nii.gz files: {total_files}")
    print(f"   Files copied successfully: {copied_count}")
    print(f"   Files with errors: {total_files - copied_count}")
    
    return copied_count > 0


input_folder = "/home/tibia/Projet_Hemorragie/MBH_SEG_2025_LLG_2025_06_12/imagesTr"
output_folder = "/home/tibia/Projet_Hemorragie/nnUNet/nnUNet_raw/Dataset002_MBH/imagesTr"
    
rename_images(input_folder, output_folder)
# Out:
# STEP 1: COPYING AND RENAMING IMAGES
# ========================================
# Input folder: /home/tibia/Projet_Hemorragie/MBH_SEG_2025_LLG_2025_06_12/imagesTr
# Output folder: /home/tibia/Projet_Hemorragie/nnUNet/nnUNet_raw/Dataset002_MBH/imagesTr
#  Copied & renamed: ID_ba3a77dd_ID_70715be365.nii.gz ➜ ID_ba3a77dd_ID_70715be365_0000.nii.gz
#  Copied & renamed: ID_552aabb9_ID_152fdcf86e.nii.gz ➜ ID_552aabb9_ID_152fdcf86e_0000.nii.gz
#  Copied & renamed: ID_af8ac3ec_ID_81a154bf08.nii.gz ➜ ID_af8ac3ec_ID_81a154bf08_0000.nii.gz
#  Copied & renamed: ID_6c70bf18_ID_3915fd7d41.nii.gz ➜ ID_6c70bf18_ID_3915fd7d41_0000.nii.gz
#  Copied & renamed: ID_a84354a5_ID_6699da85bb.nii.gz ➜ ID_a84354a5_ID_6699da85bb_0000.nii.gz
#  Copied & renamed: ID_eac5718d_ID_5a2b7690df.nii.gz ➜ ID_eac5718d_ID_5a2b7690df_0000.nii.gz
#  Copied & renamed: ID_2db7ee14_ID_f27e38fdfd.nii.gz ➜ ID_2db7ee14_ID_f27e38fdfd_0000.nii.gz
#  Copied & renamed: ID_0492041f_ID_b4fcf2f799.nii.gz ➜ ID_0492041f_ID_b4fcf2f799_0000.nii.gz
#  Copied & renamed: ID_6874ab42_ID_209e53bf66.nii.gz ➜ ID_6874ab42_ID_209e53bf66_0000.nii.gz
#  Copied & renamed: ID_5910d129_ID_094eb98167.nii.gz ➜ ID_5910d129_ID_094eb98167_0000.nii.gz
#  Copied & renamed: ID_1653b22b_ID_c35cd0de73.nii.gz ➜ ID_1653b22b_ID_c35cd0de73_0000.nii.gz
#  Copied & renamed: ID_95c4a59c_ID_47aa7ea02b.nii.gz ➜ ID_95c4a59c_ID_47aa7ea02b_0000.nii.gz
#  Copied & renamed: ID_b85bdbe9_ID_cb52cd5d53.nii.gz ➜ ID_b85bdbe9_ID_cb52cd5d53_0000.nii.gz
#  Copied & renamed: ID_56faaf6f_ID_dd8f688dff.nii.gz ➜ ID_56faaf6f_ID_dd8f688dff_0000.nii.gz
#  Copied & renamed: ID_dd3d7720_ID_6a88b9c0eb.nii.gz ➜ ID_dd3d7720_ID_6a88b9c0eb_0000.nii.gz
#  Copied & renamed: ID_c9d6fdc6_ID_7f09be285d.nii.gz ➜ ID_c9d6fdc6_ID_7f09be285d_0000.nii.gz
#  Copied & renamed: ID_9a8ad2df_ID_0ec627c99a.nii.gz ➜ ID_9a8ad2df_ID_0ec627c99a_0000.nii.gz
#  Copied & renamed: ID_90233c1a_ID_51c49c9abf.nii.gz ➜ ID_90233c1a_ID_51c49c9abf_0000.nii.gz
#  Copied & renamed: ID_596dfbc1_ID_fe7dab2602.nii.gz ➜ ID_596dfbc1_ID_fe7dab2602_0000.nii.gz
#  Copied & renamed: ID_e05b3047_ID_3d78428b2d.nii.gz ➜ ID_e05b3047_ID_3d78428b2d_0000.nii.gz
#  Copied & renamed: ID_e393f193_ID_c81bf5f45d.nii.gz ➜ ID_e393f193_ID_c81bf5f45d_0000.nii.gz
#  Copied & renamed: ID_eb5a964a_ID_c2f5350a3f.nii.gz ➜ ID_eb5a964a_ID_c2f5350a3f_0000.nii.gz
#  Copied & renamed: ID_e8691c40_ID_4e6812b21a.nii.gz ➜ ID_e8691c40_ID_4e6812b21a_0000.nii.gz
#  Copied & renamed: ID_df3f0a7d_ID_fbcdf807a8.nii.gz ➜ ID_df3f0a7d_ID_fbcdf807a8_0000.nii.gz
#  Copied & renamed: ID_0c6b97a9_ID_6011bb9ce8.nii.gz ➜ ID_0c6b97a9_ID_6011bb9ce8_0000.nii.gz
#  Copied & renamed: ID_997f19cf_ID_8fc04eb1f5.nii.gz ➜ ID_997f19cf_ID_8fc04eb1f5_0000.nii.gz
#  Copied & renamed: ID_87385103_ID_684afaed55.nii.gz ➜ ID_87385103_ID_684afaed55_0000.nii.gz
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 62
#      59 input_folder = "/home/tibia/Projet_Hemorragie/MBH_SEG_2025_LLG_2025_06_12/imagesTr"
#      60 output_folder = "/home/tibia/Projet_Hemorragie/nnUNet/nnUNet_raw/Dataset002_MBH/imagesTr"
# ---> 62 rename_images(input_folder, output_folder)
#
# Cell In[2], line 40, in rename_images(input_folder, output_folder)
#      37 try:
#      38     # Load and save to copy the file
#      39     nii_image = nib.load(input_path)
# ---> 40     nib.save(nii_image, output_path)
#      42     if "_0000" not in filename:
#      43         print(f" Copied & renamed: {filename} ➜ {new_filename}")
#
# File ~/Projet_Hemorragie/nnunet/lib/python3.12/site-packages/nibabel/loadsave.py:164, in save(img, filename, **kwargs)
#     162 # Save the type as expected
#     163 try:
# --> 164     img.to_filename(filename, **kwargs)
#     165 except ImageFileError:
#     166     pass
#
# File ~/Projet_Hemorragie/nnunet/lib/python3.12/site-packages/nibabel/filebasedimages.py:308, in FileBasedImage.to_filename(self, filename, **kwargs)
#     292 r"""Write image to files implied by filename string
#     293
#     294 Parameters
#    (...)    305 None
#     306 """
#     307 self.file_map = self.filespec_to_file_map(filename)
# --> 308 self.to_file_map(**kwargs)
#
# File ~/Projet_Hemorragie/nnunet/lib/python3.12/site-packages/nibabel/nifti1.py:2377, in Nifti1Pair.to_file_map(self, file_map, dtype)
#    2375 self.get_data_dtype(finalize=True)
#    2376 try:
# -> 2377     super().to_file_map(file_map, dtype)
#    2378 finally:
#    2379     self.set_data_dtype(img_dtype)
#
# File ~/Projet_Hemorragie/nnunet/lib/python3.12/site-packages/nibabel/analyze.py:1003, in AnalyzeImage.to_file_map(self, file_map, dtype)
#    1001 if file_map is None:
#    1002     file_map = self.file_map
# -> 1003 data = np.asanyarray(self.dataobj)
#    1004 self.update_header()
#    1005 hdr = self._header
#
# File ~/Projet_Hemorragie/nnunet/lib/python3.12/site-packages/nibabel/arrayproxy.py:454, in ArrayProxy.__array__(self, dtype)
#     433 def __array__(self, dtype=None):
#     434     """Read data from file and apply scaling, casting to ``dtype``
#     435
#     436     If ``dtype`` is unspecified, the dtype of the returned array is the
#    (...)    452         Scaled image data with type `dtype`.
#     453     """
# --> 454     arr = self._get_scaled(dtype=dtype, slicer=())
#     455     if dtype is not None:
#     456         arr = arr.astype(dtype, copy=False)
#
# File ~/Projet_Hemorragie/nnunet/lib/python3.12/site-packages/nibabel/arrayproxy.py:421, in ArrayProxy._get_scaled(self, dtype, slicer)
#     419     scl_inter = scl_inter.astype(use_dtype)
#     420 # Read array and upcast as necessary for big slopes, intercepts
# --> 421 scaled = apply_read_scaling(self._get_unscaled(slicer=slicer), scl_slope, scl_inter)
#     422 if dtype is not None:
#     423     scaled = scaled.astype(np.promote_types(scaled.dtype, dtype), copy=False)
#
# File ~/Projet_Hemorragie/nnunet/lib/python3.12/site-packages/nibabel/arrayproxy.py:391, in ArrayProxy._get_unscaled(self, slicer)
#     387 if canonical_slicers(slicer, self._shape, False) == canonical_slicers(
#     388     (), self._shape, False
#     389 ):
#     390     with self._get_fileobj() as fileobj, self._lock:
# --> 391         return array_from_file(
#     392             self._shape,
#     393             self._dtype,
#     394             fileobj,
#     395             offset=self._offset,
#     396             order=self.order,
#     397             mmap=self._mmap,
#     398         )
#     399 with self._get_fileobj() as fileobj:
#     400     return fileslice(
#     401         fileobj,
#     402         slicer,
#    (...)    407         lock=self._lock,
#     408     )
#
# File ~/Projet_Hemorragie/nnunet/lib/python3.12/site-packages/nibabel/volumeutils.py:467, in array_from_file(shape, in_dtype, infile, offset, order, mmap)
#     465 if hasattr(infile, 'readinto'):
#     466     data_bytes = bytearray(n_bytes)
# --> 467     n_read = infile.readinto(data_bytes)
#     468     needs_copy = False
#     469 else:
#
# File ~/.pyenv/versions/3.12.9/lib/python3.12/gzip.py:324, in GzipFile.read(self, size)
#     322     import errno
#     323     raise OSError(errno.EBADF, "read() on write-only GzipFile object")
# --> 324 return self._buffer.read(size)
#
# File ~/.pyenv/versions/3.12.9/lib/python3.12/_compression.py:68, in DecompressReader.readinto(self, b)
#      66 def readinto(self, b):
#      67     with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68         data = self.read(len(byte_view))
#      69         byte_view[:len(data)] = data
#      70     return len(data)
#
# File ~/.pyenv/versions/3.12.9/lib/python3.12/gzip.py:535, in _GzipReader.read(self, size)
#     533 if self._decompressor.needs_input:
#     534     buf = self._fp.read(READ_BUFFER_SIZE)
# --> 535     uncompress = self._decompressor.decompress(buf, size)
#     536 else:
#     537     uncompress = self._decompressor.decompress(b"", size)
#
# KeyboardInterrupt:

# %%
import os
import numpy as np
import nibabel as nib

def normalize_nii_images(input_folder, output_folder, min_val=-10, max_val=140):
    os.makedirs(output_folder, exist_ok=True)
    
    for filename in os.listdir(input_folder):
        if filename.endswith(".nii.gz"):
            input_path = os.path.join(input_folder, filename)
       
            output_path = os.path.join(output_folder, filename)
            
            # Load NIfTI image
            nii_image = nib.load(input_path)
            img_data = nii_image.get_fdata()
            
            # Clip values to the specified range
            img_data = np.clip(img_data, min_val, max_val)
            
            # Save processed image
            new_nii = nib.Nifti1Image(img_data, affine=nii_image.affine, header=nii_image.header)
            nib.save(new_nii, output_path)
            
            print(f"Processed: {filename}")


input_folder = "/home/tibia/Projet_Hemorragie/nnUNet/nnUNet_raw/Dataset002_MBH/imagesTr"  # Change this to your actual input folder
output_folder = input_folder # Change this to your actual output folder
normalize_nii_images(input_folder, output_folder)
# Out:
# Processed: ID_ba3a77dd_ID_70715be365_0000.nii.gz
# Processed: ID_552aabb9_ID_152fdcf86e_0000.nii.gz
# Processed: ID_af8ac3ec_ID_81a154bf08_0000.nii.gz
# Processed: ID_6c70bf18_ID_3915fd7d41_0000.nii.gz
# Processed: ID_a84354a5_ID_6699da85bb_0000.nii.gz
# Processed: ID_eac5718d_ID_5a2b7690df_0000.nii.gz
# Processed: ID_2db7ee14_ID_f27e38fdfd_0000.nii.gz
# Processed: ID_0492041f_ID_b4fcf2f799_0000.nii.gz
# Processed: ID_6874ab42_ID_209e53bf66_0000.nii.gz
# Processed: ID_5910d129_ID_094eb98167_0000.nii.gz
# Processed: ID_1653b22b_ID_c35cd0de73_0000.nii.gz
# Processed: ID_95c4a59c_ID_47aa7ea02b_0000.nii.gz
# Processed: ID_b85bdbe9_ID_cb52cd5d53_0000.nii.gz
# Processed: ID_56faaf6f_ID_dd8f688dff_0000.nii.gz
# Processed: ID_dd3d7720_ID_6a88b9c0eb_0000.nii.gz
# Processed: ID_c9d6fdc6_ID_7f09be285d_0000.nii.gz
# Processed: ID_9a8ad2df_ID_0ec627c99a_0000.nii.gz
# Processed: ID_90233c1a_ID_51c49c9abf_0000.nii.gz
# Processed: ID_596dfbc1_ID_fe7dab2602_0000.nii.gz
# Processed: ID_e05b3047_ID_3d78428b2d_0000.nii.gz
# Processed: ID_e393f193_ID_c81bf5f45d_0000.nii.gz
# Processed: ID_eb5a964a_ID_c2f5350a3f_0000.nii.gz
# Processed: ID_e8691c40_ID_4e6812b21a_0000.nii.gz
# Processed: ID_df3f0a7d_ID_fbcdf807a8_0000.nii.gz
# Processed: ID_0c6b97a9_ID_6011bb9ce8_0000.nii.gz
# Processed: ID_997f19cf_ID_8fc04eb1f5_0000.nii.gz
# Processed: ID_87385103_ID_684afaed55_0000.nii.gz
# Processed: ID_f335b6db_ID_d180629430_0000.nii.gz
# Processed: ID_3be7cc35_ID_cf2643c5a8_0000.nii.gz
# Processed: ID_2334b45f_ID_9f31e831ac_0000.nii.gz
# Processed: ID_a554892c_ID_7d5bccea0e_0000.nii.gz
# Processed: ID_727c946e_ID_e1fd84171a_0000.nii.gz
# Processed: ID_b80aec97_ID_2aa91505e6_0000.nii.gz
# Processed: ID_9dce269b_ID_4191982e02_0000.nii.gz
# Processed: ID_d02f2ee1_ID_a732858fcd_0000.nii.gz
# Processed: ID_b14c7e8b_ID_fe3a6804e3_0000.nii.gz
# Processed: ID_9ba3be10_ID_1c4e9f3c40_0000.nii.gz
# Processed: ID_80b8d734_ID_f599f2d14b_0000.nii.gz
# Processed: ID_ed6dfff7_ID_f54a5fd2c8_0000.nii.gz
# Processed: ID_7d5594ff_ID_cb535d3e8b_0000.nii.gz
# Processed: ID_2931ca43_ID_2a2b28e0ab_0000.nii.gz
# Processed: ID_6fcd55db_ID_9ed6724906_0000.nii.gz
# Processed: ID_e2e2e522_ID_7b7b5543dc_0000.nii.gz
# Processed: ID_ccbe16e6_ID_706deb5ba2_0000.nii.gz
# Processed: ID_b972b07f_ID_b5ace7f563_0000.nii.gz
# Processed: ID_8d914da6_ID_b4eb9c8234_0000.nii.gz
# Processed: ID_ab1ba874_ID_0c1c9bf0ae_0000.nii.gz
# Processed: ID_751df220_ID_4c26128a8d_0000.nii.gz
# Processed: ID_d9675573_ID_02237f7694_0000.nii.gz
# Processed: ID_eb39f236_ID_d7edccdb08_0000.nii.gz
# Processed: ID_4681a956_ID_5b133aa2c0_0000.nii.gz
# Processed: ID_5e405f44_ID_7a773f615f_0000.nii.gz
# Processed: ID_a40e10b0_ID_18c55dad14_0000.nii.gz
# Processed: ID_7f065b1e_ID_4c02f6eaaf_0000.nii.gz
# Processed: ID_88dbe13f_ID_01c5078fbf_0000.nii.gz
# Processed: ID_790acb3f_ID_c294f81468_0000.nii.gz
# Processed: ID_47aa2b3a_ID_95a9953aba_0000.nii.gz
# Processed: ID_75448f16_ID_780b14c9d7_0000.nii.gz
# Processed: ID_5117f9bf_ID_14d96feecf_0000.nii.gz
# Processed: ID_39702b69_ID_167ab8c629_0000.nii.gz
# Processed: ID_a9fe41fd_ID_ba000cea10_0000.nii.gz
# Processed: ID_5ca2154a_ID_d4984e0dcc_0000.nii.gz
# Processed: ID_cb4c887c_ID_ec2a4643f3_0000.nii.gz
# Processed: ID_2db7ee14_ID_2591d00dfc_0000.nii.gz
# Processed: ID_94271e7f_ID_50fb725eb8_0000.nii.gz
# Processed: ID_ca7bbeab_ID_228e9cbe5c_0000.nii.gz
# Processed: ID_089596a9_ID_ea71b57820_0000.nii.gz
# Processed: ID_9e0eaeeb_ID_be5b5b11eb_0000.nii.gz
# Processed: ID_7860208e_ID_f68c193b69_0000.nii.gz
# Processed: ID_09b33fc4_ID_bcd322d4ed_0000.nii.gz
# Processed: ID_87e60d98_ID_0c2d2758ae_0000.nii.gz
# Processed: ID_2872834a_ID_542e9d00da_0000.nii.gz
# Processed: ID_693f2d48_ID_06a88c0e8b_0000.nii.gz
# Processed: ID_98450f26_ID_8d66ffdc94_0000.nii.gz
# Processed: ID_5f53ab26_ID_f1c7d54a53_0000.nii.gz
# Processed: ID_253e809f_ID_095d8c391f_0000.nii.gz
# Processed: ID_eb093f57_ID_0e2b33b4c9_0000.nii.gz
# Processed: ID_0237f3c9_ID_40015688b9_0000.nii.gz
# Processed: ID_199b0a56_ID_09e623e993_0000.nii.gz
# Processed: ID_a2ddcdfe_ID_d7aedfd21f_0000.nii.gz
# Processed: ID_e566ef9b_ID_439ce9720b_0000.nii.gz
# Processed: ID_0c3eef60_ID_6994ad7df0_0000.nii.gz
# Processed: ID_e1d9fe9d_ID_f73aea5186_0000.nii.gz
# Processed: ID_df935041_ID_32b8592d2c_0000.nii.gz
# Processed: ID_c3769f3a_ID_32fc557515_0000.nii.gz
# Processed: ID_7e8279ce_ID_75522ba124_0000.nii.gz
# Processed: ID_acaa9bd1_ID_02fe96388e_0000.nii.gz
# Processed: ID_16ed917a_ID_145f184354_0000.nii.gz
# Processed: ID_6a6976ae_ID_97ae10a424_0000.nii.gz
# Processed: ID_7db5845a_ID_0c7cd6982b_0000.nii.gz
# Processed: ID_e3db11e0_ID_1863688c5b_0000.nii.gz
# Processed: ID_10c64d22_ID_4c9aad31ca_0000.nii.gz
# Processed: ID_2e21c3f3_ID_bc8f99a0cc_0000.nii.gz
# Processed: ID_82cfc6a8_ID_da93401499_0000.nii.gz
# Processed: ID_a9b3fedc_ID_3850bef0a3_0000.nii.gz
# Processed: ID_c5479170_ID_6cc8f5463a_0000.nii.gz
# Processed: ID_c1e1c4ef_ID_521bc36497_0000.nii.gz
# Processed: ID_6caf8d60_ID_3634a47122_0000.nii.gz
# Processed: ID_1879071b_ID_4b8e1377e7_0000.nii.gz
# Processed: ID_4e227c9c_ID_d8607fa88e_0000.nii.gz
# Processed: ID_1cbe2853_ID_37afefdc7c_0000.nii.gz
# Processed: ID_d29d246b_ID_6121b401e7_0000.nii.gz
# Processed: ID_346de481_ID_2e8fea0d9a_0000.nii.gz
# Processed: ID_4e25e744_ID_b0275c19cd_0000.nii.gz
# Processed: ID_14058625_ID_527c581583_0000.nii.gz
# Processed: ID_fcbe7eda_ID_5726e1c630_0000.nii.gz
# Processed: ID_41a55df8_ID_ca0abe844a_0000.nii.gz
# Processed: ID_ad252872_ID_74f728bfad_0000.nii.gz
# Processed: ID_39e94772_ID_f1a5ef6a24_0000.nii.gz
# Processed: ID_a768755c_ID_3541b002ac_0000.nii.gz
# Processed: ID_a1703be5_ID_d0e02f0443_0000.nii.gz
# Processed: ID_3e481fc5_ID_750530c215_0000.nii.gz
# Processed: ID_77cd921b_ID_e0d0a5f299_0000.nii.gz
# Processed: ID_69e721e0_ID_a6f36605d7_0000.nii.gz
# Processed: ID_029ebbea_ID_563afa0901_0000.nii.gz
# Processed: ID_d79fa3ff_ID_90d02c54ba_0000.nii.gz
# Processed: ID_faa3c13d_ID_c31106b8dc_0000.nii.gz
# Processed: ID_181aab15_ID_062634d043_0000.nii.gz
# Processed: ID_a429fd9a_ID_2eabc43f3d_0000.nii.gz
# Processed: ID_3343ddf2_ID_fddff2e9c1_0000.nii.gz
# Processed: ID_9cc1c1a0_ID_8fb44d82d0_0000.nii.gz
# Processed: ID_b367130b_ID_debc60a9ba_0000.nii.gz
# Processed: ID_73cae446_ID_852cb06998_0000.nii.gz
# Processed: ID_c488fbef_ID_ae4af6dd21_0000.nii.gz
# Processed: ID_07365cde_ID_8e661b8f07_0000.nii.gz
# Processed: ID_58d2ebfa_ID_76487f508f_0000.nii.gz
# Processed: ID_85f42dd5_ID_a0ef1a9eaf_0000.nii.gz
# Processed: ID_041e6601_ID_1fa1d20bba_0000.nii.gz
# Processed: ID_02b882cc_ID_a4892e60ae_0000.nii.gz
# Processed: ID_56983eda_ID_a1eb0918d6_0000.nii.gz
# Processed: ID_18747540_ID_1eb1de9633_0000.nii.gz
# Processed: ID_90b88b8b_ID_8d39c61ccd_0000.nii.gz
# Processed: ID_b79a2d4a_ID_710cdb6530_0000.nii.gz
# Processed: ID_811a274b_ID_fa1c9402fb_0000.nii.gz
# Processed: ID_495ac92a_ID_4daa7b9cc7_0000.nii.gz
# Processed: ID_db89259c_ID_2c20aff0f9_0000.nii.gz
# Processed: ID_3bda60be_ID_067209cc9a_0000.nii.gz
# Processed: ID_b92014da_ID_a9310805a0_0000.nii.gz
# Processed: ID_b3a33085_ID_175a5c4119_0000.nii.gz
# Processed: ID_9ed18606_ID_8cfe740d83_0000.nii.gz
# Processed: ID_4a16396b_ID_1f3e0c2c5c_0000.nii.gz
# Processed: ID_66a9a60e_ID_3a4f389a07_0000.nii.gz
# Processed: ID_5adb32dc_ID_35dd6d3d56_0000.nii.gz
# Processed: ID_977da27d_ID_7ca7e2a2e4_0000.nii.gz
# Processed: ID_2a42d0a0_ID_5fdc3fb915_0000.nii.gz
# Processed: ID_39bdd84b_ID_a318f304e4_0000.nii.gz
# Processed: ID_02f779fb_ID_c4d7f33559_0000.nii.gz
# Processed: ID_daf22e49_ID_bf76e84f8d_0000.nii.gz
# Processed: ID_6c85adda_ID_86bc0ab248_0000.nii.gz
# Processed: ID_cf8f428f_ID_61ec5a3e22_0000.nii.gz
# Processed: ID_d8e67d7d_ID_c182bd8176_0000.nii.gz
# Processed: ID_d3d99dce_ID_cd10b6aba1_0000.nii.gz
# Processed: ID_9631ec18_ID_c205d02b10_0000.nii.gz
# Processed: ID_c91d516c_ID_2d2f3d2953_0000.nii.gz
# Processed: ID_f4795940_ID_6317a06429_0000.nii.gz
# Processed: ID_d039497d_ID_da6cc2290f_0000.nii.gz
# Processed: ID_981d95a4_ID_ec08553ddc_0000.nii.gz
# Processed: ID_2949cdc6_ID_dcb864c93f_0000.nii.gz
# Processed: ID_05331dc6_ID_47213b7e2e_0000.nii.gz
# Processed: ID_19d26713_ID_9f54cdc920_0000.nii.gz
# Processed: ID_8d326f80_ID_87b6843dde_0000.nii.gz
# Processed: ID_b1d5d5e8_ID_4cfa36b63f_0000.nii.gz
# Processed: ID_55742eb7_ID_7d5ad548ca_0000.nii.gz
# Processed: ID_ea687366_ID_452c5f1f8c_0000.nii.gz
# Processed: ID_63862d24_ID_24f0f2ff02_0000.nii.gz
# Processed: ID_98fcfe52_ID_a8bbf4336d_0000.nii.gz
# Processed: ID_196704db_ID_4eb6296376_0000.nii.gz
# Processed: ID_3dab46e7_ID_e837f87e46_0000.nii.gz
# Processed: ID_30d19531_ID_cf607a5cd7_0000.nii.gz
# Processed: ID_4ec93c83_ID_b76a4106f8_0000.nii.gz
# Processed: ID_fb6d0135_ID_497840f16e_0000.nii.gz
# Processed: ID_0b10cbee_ID_f91d6a7cd2_0000.nii.gz
# Processed: ID_96967deb_ID_5d782e9379_0000.nii.gz
# Processed: ID_d2deede6_ID_799247e354_0000.nii.gz
# Processed: ID_c08a7b51_ID_b98f437f69_0000.nii.gz
# Processed: ID_aaf2973d_ID_4002bc3ced_0000.nii.gz
# Processed: ID_338738e7_ID_0808281b2a_0000.nii.gz
# Processed: ID_268b38fe_ID_d747ae3ffb_0000.nii.gz
# Processed: ID_8e8df8c0_ID_857231e0c6_0000.nii.gz
# Processed: ID_83a07ec6_ID_ef148a90ed_0000.nii.gz
# Processed: ID_10beb45f_ID_7184e80f09_0000.nii.gz
# Processed: ID_f1a342da_ID_13d6f969d2_0000.nii.gz
# Processed: ID_50b54af0_ID_fbeeed4370_0000.nii.gz
# Processed: ID_46cd34ad_ID_3003623499_0000.nii.gz
# Processed: ID_cdaa21cb_ID_a5f7ae30f1_0000.nii.gz
# Processed: ID_6bb6dd02_ID_dd6370b417_0000.nii.gz
# Processed: ID_ec8a7bf0_ID_c853ba89ce_0000.nii.gz
# Processed: ID_69b19057_ID_44d0da38f2_0000.nii.gz
# Processed: ID_96cd5341_ID_41b80bd3ec_0000.nii.gz
# Processed: ID_e714812a_ID_11a3b1afdc_0000.nii.gz
# Processed: ID_92ef7cc4_ID_b0c4006e93_0000.nii.gz
# Processed: ID_a72de500_ID_87b2b4fc60_0000.nii.gz

# %%
import os
import numpy as np
import nibabel as nib



def check_clip_values(input_folder, min_val=-10, max_val=140):
    for filename in os.listdir(input_folder):
        if filename.endswith(".nii.gz"):
            input_path = os.path.join(input_folder, filename)
            
            # Charge l'image NIfTI
            nii_image = nib.load(input_path)
            img_data = nii_image.get_fdata()
            
            # Vérifie les valeurs min et max de l'image traitée
            clip_min = np.min(img_data)
            clip_max = np.max(img_data)
            
            # Affiche les résultats
            print(f"Fichier : {filename} | Min: {clip_min} | Max: {clip_max}")
            
            # Vérifie si les valeurs sont dans le bon range
            if clip_min < min_val or clip_max > max_val:
                print(f"Attention ! {filename} dépasse les bornes après le clip")
            else:
                print(f"{filename} a bien été clipé dans la plage {min_val} - {max_val}")

if __name__ == "__main__":
    input_folder = "/home/tibia/Projet_Hemorragie/mbh_seg/nii/test/images"
    
    check_clip_values(input_folder)
# Out:
# Fichier : ID_0219ef88_ID_e5c1a31210_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_0219ef88_ID_e5c1a31210_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_066b1fc2_ID_f937d7bff0_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_066b1fc2_ID_f937d7bff0_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_095c522a_ID_19cfefdccb_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_095c522a_ID_19cfefdccb_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_0a040036_ID_44cc017f8a_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_0a040036_ID_44cc017f8a_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_0a0e8fbe_ID_7f6c5ed050_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_0a0e8fbe_ID_7f6c5ed050_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_0bee00a2_ID_0b9e78b135_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_0bee00a2_ID_0b9e78b135_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_0c45b337_ID_8fd676c7ac_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_0c45b337_ID_8fd676c7ac_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_0cdd2365_ID_bcc6fbef0d_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_0cdd2365_ID_bcc6fbef0d_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_0d0f361b_ID_17542973dc_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_0d0f361b_ID_17542973dc_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_0d5dae65_ID_186e627ed9_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_0d5dae65_ID_186e627ed9_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_0df4e645_ID_d14c8c9b99_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_0df4e645_ID_d14c8c9b99_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_0e8ba35b_ID_d60ed297ea_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_0e8ba35b_ID_d60ed297ea_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_0f320c56_ID_27f2bce652_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_0f320c56_ID_27f2bce652_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_0faab8a8_ID_df9d49e5e6_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_0faab8a8_ID_df9d49e5e6_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_0fb0d3d2_ID_6270e85cb5_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_0fb0d3d2_ID_6270e85cb5_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_0ff437c4_ID_0c9a06814c_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_0ff437c4_ID_0c9a06814c_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_1aff4c26_ID_94bbe7f6cc_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_1aff4c26_ID_94bbe7f6cc_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_1b5a3933_ID_856868cbfd_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_1b5a3933_ID_856868cbfd_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_1b5cfeda_ID_6e06ec9a1f_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_1b5cfeda_ID_6e06ec9a1f_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_1bd90426_ID_44493c1d26_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_1bd90426_ID_44493c1d26_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_1c3da1cd_ID_cbb8a2936b_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_1c3da1cd_ID_cbb8a2936b_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_1dfa5b21_ID_02cd74218f_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_1dfa5b21_ID_02cd74218f_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_1ea1a5cd_ID_f7ffcd3292_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_1ea1a5cd_ID_f7ffcd3292_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_1ea8a377_ID_38c12664cf_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_1ea8a377_ID_38c12664cf_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_1f2017cd_ID_bfab570858_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_1f2017cd_ID_bfab570858_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_1fcb892c_ID_908ec8ac6e_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_1fcb892c_ID_908ec8ac6e_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_26aa5747_ID_da121424ef_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_26aa5747_ID_da121424ef_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_28e80c22_ID_bf9876ebdd_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_28e80c22_ID_bf9876ebdd_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_2a712323_ID_7ef0ade00a_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_2a712323_ID_7ef0ade00a_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_2b30b4fa_ID_4fe3d97dd4_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_2b30b4fa_ID_4fe3d97dd4_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_2b7cc24e_ID_6fea1c1fb3_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_2b7cc24e_ID_6fea1c1fb3_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_3aa50c55_ID_9bed05390d_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_3aa50c55_ID_9bed05390d_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_3fa11bf9_ID_9a7a61f482_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_3fa11bf9_ID_9a7a61f482_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_3fd996e7_ID_3d4c47c7a4_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_3fd996e7_ID_3d4c47c7a4_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_4c27e050_ID_4148891184_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_4c27e050_ID_4148891184_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_4df69bae_ID_e5bd3504d8_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_4df69bae_ID_e5bd3504d8_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_4e970d93_ID_2713bc273b_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_4e970d93_ID_2713bc273b_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_5ae36db5_ID_17014b11f1_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_5ae36db5_ID_17014b11f1_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_5e61b52f_ID_0f080d4194_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_5e61b52f_ID_0f080d4194_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_5fe1b289_ID_0f30dec3b3_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_5fe1b289_ID_0f30dec3b3_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_6f5384b7_ID_1dae254908_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_6f5384b7_ID_1dae254908_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_75e616a8_ID_8ce0debeb1_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_75e616a8_ID_8ce0debeb1_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_7742a473_ID_9f006ce4ef_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_7742a473_ID_9f006ce4ef_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_7b1f4a51_ID_0b4e0df673_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_7b1f4a51_ID_0b4e0df673_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_7eeb6638_ID_02d57cd50b_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_7eeb6638_ID_02d57cd50b_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_8bb2daac_ID_f1994421cc_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_8bb2daac_ID_f1994421cc_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_90ae3af3_ID_8d77fcb5d2_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_90ae3af3_ID_8d77fcb5d2_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_93e3cc83_ID_c0e899cc25_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_93e3cc83_ID_c0e899cc25_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_96bb7e1d_ID_4b827bde69_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_96bb7e1d_ID_4b827bde69_0000.nii.gz a bien été clipé dans la plage -10 - 140
# Fichier : ID_fd77bee7_ID_60083050a8_0000.nii.gz | Min: -10.0 | Max: 139.9999999650754
# ID_fd77bee7_ID_60083050a8_0000.nii.gz a bien été clipé dans la plage -10 - 140
